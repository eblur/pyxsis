# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

import os
from scipy.optimize import minimize

import clarsach
import xpysis

# %matplotlib inline

# %%
DATA_DIR = os.environ['HOME'] + "/dev/clarsach/data"
mrk_dir  = DATA_DIR + "/tgcat/obs_15477_tgid_4679/"
mrk_heg1_file = mrk_dir + "heg_1.pha"

# %%
mrk421 = xpysis.Spectrum(mrk_heg1_file, telescope='HETG')

# %%
ax = plt.subplot(111)
xpysis.plot_unfold(ax, mrk421, xunit='keV')
plt.loglog()
# Out:
# []

# %% [markdown]
# ## Test notice functionality

# %%
mrk421.notice_values(1.0, 8.0, unit='keV')

# %%
lo, hi, mid, cts = mrk421.bin_counts()

# %%
ax = plt.subplot(111)
xpysis.plot_unfold(ax, mrk421, xunit='angs')
plt.loglog()
# Out:
# []

# %% [markdown]
# ## Test binning functionality

# %%
mrk421.notice_all()

# %%
xpysis.group_channels(mrk421, 5)

# %%
mrk421.binning
# Out:
# array([    0.,     0.,     0., ...,  1637.,  1638.,  1638.])

# %%
len(mrk421.counts) / 5
# Out:
# 1638

# %%
# %%time
test_lo, test_hi, test_counts = mrk421._parse_binning()
# Out:
# CPU times: user 60 ms, sys: 0 ns, total: 60 ms
# Wall time: 61.1 ms

# %%
plt.step(test_lo, test_counts)

# %%
ax = plt.subplot(111)
xpysis.plot_counts(ax, mrk421, xunit='keV')

# %%
ax = plt.subplot(111)
xpysis.plot_unfold(ax, mrk421, xunit='keV')
plt.loglog()
# Out:
# []

# %%
mrk421.reset_binning()

ax = plt.subplot(111)
xpysis.plot_unfold(ax, mrk421)
plt.loglog()
# Out:
# []

# %%
xpysis.group_mincounts(mrk421, 10)

# %%
# %%time
test_lo, test_hi, test_counts = mrk421._parse_binning()
# Out:
# CPU times: user 92 ms, sys: 0 ns, total: 92 ms
# Wall time: 89.5 ms

# %%
all(test_counts >= 10)
# Out:
# True

# %%
ax = plt.subplot(111)
xpysis.plot_counts(ax, mrk421)

# %%
ax = plt.subplot(111)
xpysis.plot_unfold(ax, mrk421)
plt.loglog()
# Out:
# []

# %%
mrk421.notice_values(1.0, 8.0, unit='keV')

# %%
ax = plt.subplot(111)
xpysis.plot_unfold(ax, mrk421)
plt.loglog()
# Out:
# []

# %%
mrk421.notice_values(1.0, 15.0, unit='angs')

ax = plt.subplot(111)
xpysis.plot_unfold(ax, mrk421, xunit='angs')
plt.semilogy()
# Out:
# []
